# %%
# !pip install langchain
# !pip install langchain_groq
# !pip install -U langchain-community
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain_groq in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (0.2.3)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain_groq) (0.15.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain_groq) (0.3.31)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (2.10.5)
# Requirement already satisfied: sniffio in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_groq) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_groq) (0.2.11)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_groq) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain_groq) (9.0.0)
# Requirement already satisfied: idna>=2.8 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.10)
# Requirement already satisfied: certifi in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain_groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain_groq) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain_groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain_groq) (2.3.0)
# Requirement already satisfied: langchain-community in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.15 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.3.31)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.2.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: langchain-community in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.15 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.3.31)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.2.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain<0.4.0,>=0.3.15->langchain-community) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.15->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)

# %% [markdown]
# # Logical Routing

# %%
from typing import Literal

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_groq import ChatGroq

# %%
from typing import Literal

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_groq import ChatGroq

# Data model
class RouteQuery(BaseModel):
    """Route a user query to the most relevant datasource."""

    datasource: Literal["python_docs", "cython_docs", "java_docs"] = Field(
        ...,
        description="Given a user question choose which datasource would be most relevant for answering their question",
    )

# LLM with function call 
llm = ChatGroq(api_key="api key",temperature=0)
structured_llm = llm.with_structured_output(RouteQuery)

# Prompt 
system = """You are an expert at routing a user question to the appropriate data source.

Based on the programming language the question is referring to, route it to the relevant data source."""

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "{question}"),
    ]
)

# Define router 
router = prompt | structured_llm

# %%
question = """Why doesn't the following code work:

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(["human", "speak in {language}"])
prompt.invoke("french")
"""

result = router.invoke({"question": question})

# %%
result
# Out:
# RouteQuery(datasource='python_docs')

# %%
def choose_route(result):
    if "python_docs" in result.datasource.lower():
        ### Logic here 
        return "chain for python_docs"
    elif "cython_docs" in result.datasource.lower():
        ### Logic here 
        return "chain for cython_docs"
    else:
        ### Logic here 
        return "java_docs"

from langchain_core.runnables import RunnableLambda

full_chain = router | RunnableLambda(choose_route)

# %%
full_chain.invoke({"question": question})
# Out:
# 'chain for python_docs'

# %% [markdown]
# # Semantic Routing

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: tqdm in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (1.15.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavansomisetty\anaconda3\envs\chatai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)

# %%
from langchain_community.utils.math import cosine_similarity
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

# Two prompts
physics_template = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise and easy to understand manner. \
When you don't know the answer to a question you admit that you don't know.

Here is a question:
{query}"""

math_template = """You are a very good mathematician. You are great at answering math questions. \
You are so good because you are able to break down hard problems into their component parts, \
answer the component parts, and then put them together to answer the broader question.

Here is a question:
{query}"""

# Embed prompts
model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf_embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
prompt_templates = [physics_template, math_template]
prompt_embeddings = hf_embeddings.embed_documents(prompt_templates)

# Route question to prompt 
def prompt_router(input):
    # Embed question
    query_embedding = hf_embeddings.embed_query(input["query"])
    # Compute similarity
    similarity = cosine_similarity([query_embedding], prompt_embeddings)[0]
    most_similar = prompt_templates[similarity.argmax()]
    # Chosen prompt 
    print("Using MATH" if most_similar == math_template else "Using PHYSICS")
    return PromptTemplate.from_template(most_similar)


chain = (
    {"query": RunnablePassthrough()}
    | RunnableLambda(prompt_router)
    | ChatGroq(api_key="api key")
    | StrOutputParser()
)

print(chain.invoke("What's a E=mc^2"))
# Out:
# Using PHYSICS
# E=mc^2 is the mass-energy equivalence formula discovered by Albert Einstein. It shows that energy (E) is equal to mass (m) times the speed of light (c) squared. This means that mass and energy are interchangeable and can be converted into each other. For example, when a small amount of mass is converted into energy during a nuclear reaction, a large amount of energy is released.
